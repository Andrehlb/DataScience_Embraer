# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrehlb/DataScience_Embraer/blob/main/matPlt1_Andrehlb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x = ['vinicius','thiago','cconic']
y = [4,5,6]
z = [7,8,9]

plt.plot(x,y,z)
plt.legend(x)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [4,5,6]
y = [7,8,9]
z = []

plt.plot(x)
plt.plot(y)
plt.plot(z)
plt.legend(['Vinícius', 'Thiago', 'Cocnic'], loc ="upper left")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [4,5,6]
y = [7,8,9]

x = ['vinicius','thiago','cconic']
plt.plot(x)
plt.plot(y)
plt.plot(z)
plt.legend(x)
plt.show()

# %%
#from re import X
#fig = plt.figure(figsize=(10,5))
#ax = fig.add_subplot(111)
#ax.legend(loc='best')
#

# %%
# importing modules
import numpy as np
import matplotlib.pyplot as plt
  
# Y-axis values
y1 = [2, 3, 4.5]
  
# Y-axis values 
y2 = [1, 1.5, 5]
  
# Function to plot  
plt.plot(y1)
plt.plot(y2)
  
# Function add a legend  
plt.legend(["blue", "green"], loc ="lower right")
  
# function to show the plot
plt.show()
