# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrehlb/DataScience_Embraer/blob/main/Aula_3_2_Introdu%C3%A7%C3%A3o_ao_Pandas_pratica_Prof_Matheus_Andrehlb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importação do pandas
import pandas as pd
import numpy as np

# %% [markdown]
# <h1> Leitura de Dados </h1>

# %%
pd.read_csv?

# %%
#leitura dos dados do cvs
df = pd.read_csv('http://pycourse.s3.amazonaws.com/temperature.csv')
df
# Out:
#          date  temperatura classification
# 0  2020-01-01         29.1         quente
# 1  2020-02-01         31.2   muito quente
# 2  2020-03-01         28.5         quente
# 3  2020-04-01         28.0         quente
# 4  2020-05-01         24.0    confortavel
# 5  2020-06-01         20.0           frio

# %%
#leitura de planilhas excel
#2 abas (worksheet)
excel_file = pd.ExcelFile('http://pycourse.s3.amazonaws.com/temperature.xlsx')

# %%
type(excel_file)
# Out:
# pandas.io.excel._base.ExcelFile

# %%
#leitura da primeira aba (sheet1)
#dados numéricos com separador decimal = '.'
df2 = pd.read_excel(excel_file, sheet_name='Sheet1')
df
# Out:
#          date  temperatura classification
# 0  2020-01-01         29.1         quente
# 1  2020-02-01         31.2   muito quente
# 2  2020-03-01         28.5         quente
# 3  2020-04-01         28.0         quente
# 4  2020-05-01         24.0    confortavel
# 5  2020-06-01         20.0           frio

# %%
#leitura da primeira aba (sheet2)
#dados numéricos com separador decimal = '.'
df2 = pd.read_excel(excel_file, sheet_name='Sheet2', decial=',', **kwargs)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-de87b566ac2b> in <module>
#       1 #leitura da primeira aba (sheet2)
#       2 #dados numéricos com separador decimal = '.'
# ----> 3 df2 = pd.read_excel(excel_file, sheet_name='Sheet2', decial=',', **kwargs)
#       4 df
#
# NameError: name 'kwargs' is not defined

# %%
#leitura da segunda aba (sheet2) que tem, dados numéricos, com vírgula como separador decimal
#será informado para considerar o separador commo ponto
# !pip install openpyxl
df3 = pd.read_excel(excel_file, sheet_name='Sheet2') #sem fazer a informação
df3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#         date temperatura classification
# 0 2020-01-01        29,1         quente
# 1 2020-02-01        31,2   muito quente
# 2 2020-03-01        28,5         quente
# 3 2020-04-01        28,0         quente
# 4 2020-05-01        24,0    confortavel
# 5 2020-06-01        20,0           frio

# %%
#Instalação sugerida pelo Proferssor Ricardo
# !pip install pandas==1.0.5

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport
df=pd.read_excel("https://pycourse.s3.amazonaws.com/temperature.xlsx")
df.head()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#         date  temperatura classification
# 0 2020-01-01         29.1         quente
# 1 2020-02-01         31.2   muito quente
# 2 2020-03-01         28.5         quente
# 3 2020-04-01         28.0         quente
# 4 2020-05-01         24.0    confortavel

# %%
#leitura da segunda aba (sheet2) que tem, dados numéricos, com vírgula como separador decimal
#será informado para considerar o separador commo ponto
df3 = pd.read_excel(excel_file, sheet_name='Sheet2', decimal = ',') 
df3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-501a1cc5ca94> in <module>
#       1 #leitura da segunda aba (sheet2) que tem, dados numéricos, com vírgula como separador decimal
#       2 #será informado para considerar o separador commo ponto
# ----> 3 df3 = pd.read_excel(excel_file, sheet_name='Sheet2', decimal = ',')
#       4 df3
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309     Usage: construct a docstring.Appender with a string to be joined to
#     310     the original docstring. An optional 'join' parameter may be supplied
# --> 311     which will be used to join the docstring and addendum. e.g.
#     312
#     313     add_copyright = Appender("Copyright (c) 2009", join='\n')
#
# TypeError: read_excel() got an unexpected keyword argument 'decimal'

# %%
# Out:
# Object `decimal` not found.
